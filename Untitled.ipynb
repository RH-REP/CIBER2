# %%
import os
import csv
import matplotlib.pyplot as plt
import numpy as np
x = np.array((0,1,2,3))
y = np.array((0,100,200,300))

# os.makedirs("./csv")
file = "./csv/test"
with open(file,'w',newline='')  as f :
    csv_writer = csv.writer(f) #ファイルオブジェクトをcsv.writerオブジェクトに変換
    csv_writer.writerows(np.array((x,y))) #行一括追加

# %%
display(fig)
