# %%
# %load_ext memory_profiler
import matplotlib.pyplot as plt
import matplotlib
import os
from fits_reader import shelf
from fits_reader import fits_reader
import importlib
import glob
importlib.reload(fits_reader)
importlib.reload(shelf)
import gc
# %matplotlib notebook
arms = ["armS","armM","armL"]
home_directory = os.environ['HOME']
season_name = "/202106_flight"
experiment_name = "/FITS"
experiment_directory = home_directory + season_name + experiment_name
exp_shelf = shelf.make_ramp_shelf(experiment_directory)
chs = ["ch1","ch2","ch3"]
# for ch in chs:
book = "flight" 
folders = glob.glob(experiment_directory+"/frames/ch1/*" )
exp_shelf.line_up_by_folders(book,folders)
cut_area = fits_reader.AreaSizeClass(1100,1200,1400,1500)
# Out:
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler

# %%
exp_shelf.show_all_books()
# Out:
# ['flight']
# ['flight']

# %%
arm = arms[0]
book = "flight"
exp_shelf.cut_area = cut_area
fig,ax = exp_shelf.make_flight_sequence_graph(book,arm)
plt.close(fig)
# Out:
# start time , 148.5
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-17-b6150dc66e3f> in <module>
#       2 book = "flight"
#       3 exp_shelf.cut_area = cut_area
# ----> 4 fig,ax = exp_shelf.make_flight_sequence_graph(book,arm)
#       5 plt.close(fig)
#
# ~/python/main/calibration/fits_reader/shelf.py in make_flight_sequence_graph(self, book_name, arm_name)
#     241
#     242         for f in working_directory:
# --> 243             times, average_counts_of_area,_ =self.calc_ramp_data(f,arm_name,)
#     244             times_np = np.append(times_np,times+last_time)
#     245             last_time = times_np[-1]
#
# ~/python/main/calibration/fits_reader/shelf.py in calc_ramp_data(self, folder_name, arm_name)
#     382     def calc_ramp_data(self,folder_name,arm_name,):
#     383         cut_area = self.cut_area
# --> 384         times, data_image_minus_reset = self._get_data(arm_name,folder_name)
#     385         if times == []:
#     386             return [],[],[]
#
# ~/python/main/calibration/fits_reader/shelf.py in _get_data(self, arm_name, folder_name)
#     373         if self.isMask:
#     374             mask,_ = fits_reader.loadMask(ch)
# --> 375             data_image = data_image * mask
#     376             if self.minus_reset_frame:
#     377                 reset_image = self._getResetImage(ch)
#
# MemoryError: Unable to allocate 2.61 GiB for an array with shape (167, 2048, 2048) and data type float32

# %%
fig.set_figwidth(9)
fig.set_figheight(5)
display(fig)
ax.set_xlim(100,500)
ax.set_ylim(-500,2000)
display(fig)

# %%
arm = arms[1]
book = "flight"
fig2,ax2 = exp_shelf.make_flight_sequence_graph(book,arm,cutArea,)
plt.close(fig2)
# Out:
# start time , 147.0
# 29233.0

# %%
fig2.set_figwidth(9)
fig2.set_figheight(5)
display(fig2)
ax2.set_ylim(-500,500)
ax2.set_xlim(100,500)
display(fig2)

# %%
arm = arms[2]
book = "flight"
fig3,ax3 = exp_shelf.make_flight_sequence_graph(book,arm,cutArea,)
plt.close(fig3)
# Out:
# start time , 128.70000000000002
# 213755.0

# %%
fig3.set_figwidth(9)
fig3.set_figheight(5)
display(fig3)
ax3.set_ylim(-1000,10000)
ax3.set_xlim(100,500)
display(fig3)
