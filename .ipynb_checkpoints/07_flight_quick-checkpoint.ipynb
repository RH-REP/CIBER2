# %%
# %load_ext memory_profiler
import matplotlib.pyplot as plt
import matplotlib
import os
from fits_reader import shelf
from fits_reader import fits_reader
import importlib
import glob
importlib.reload(fits_reader)
importlib.reload(shelf)
import gc
# %matplotlib notebook
arms = ["armS","armM","armL"]
home_directory = os.environ['HOME']
season_name = "/202106_flight"
experiment_name = "/FITS"
experiment_directory = home_directory + season_name + experiment_name
exp_shelf = shelf.make_ramp_shelf(experiment_directory)
chs = ["ch1","ch2","ch3"]
# for ch in chs:
book = "flight" 
folders = glob.glob(experiment_directory+"/frames/ch1/*" )
exp_shelf.line_up_by_folders(book,folders)
cut_area = fits_reader.AreaSizeClass(1100,1200,1400,1500)
# Out:
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler

# %%
exp_shelf.show_all_books()
# Out:
# ['flight']
# ['flight']

# %%
arm = arms[0]
book = "flight"
exp_shelf.cut_area = cut_area

# %%
print(exp_shelf.cut_area)
# Out:
# <fits_reader.fits_reader.AreaSizeClass object at 0x7f44009532b0>

# %%
fig,ax = exp_shelf.make_flight_sequence_graph(book,arm,)
# times = exp_shelf.make_flight_sequence_graph(book,arm,)
# plt.close(fig)
# print(times)
# Out:
# start time , 148.5
# slope is  2.846304244334453
# slope is  172.1958509710751
# 17679.0

# %%
fig.set_figwidth(9)
fig.set_figheight(5)
display(fig)
ax.set_xlim(100,500)
ax.set_ylim(-500,2000)
display(fig)

# %%
arm = arms[1]
book = "flight"
fig2,ax2 = exp_shelf.make_flight_sequence_graph(book,arm,)
plt.close(fig2)
# Out:
# start time , 147.0
# slope is  0.660809461619505
# slope is  283.4178515082217
# 29233.0

# %%
fig2.set_figwidth(9)
fig2.set_figheight(5)
display(fig2)
ax2.set_ylim(-500,500)
ax2.set_xlim(100,500)
display(fig2)

# %%
arm = arms[2]
book = "flight"
fig3,ax3 = exp_shelf.make_flight_sequence_graph(book,arm,)
plt.close(fig3)
# Out:
# start time , 148.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-376bcdf8df63> in <module>
#       1 arm = arms[2]
#       2 book = "flight"
# ----> 3 fig3,ax3 = exp_shelf.make_flight_sequence_graph(book,arm,)
#       4 plt.close(fig3)
#
# ~/python/main/calibration/fits_reader/shelf.py in make_flight_sequence_graph(self, book_name, arm_name, isBg)
#     252         for f in working_directory:
#     253             # times, average_counts_of_area, _ = self.calc_ramp_data(f,arm_name,)
# --> 254             times, average_counts_of_area, = self.calc_ramp_data(f,arm_name,)
#     255             times_np = np.append(times_np,times+last_time)
#     256             last_time = times_np[-1]
#
# ~/python/main/calibration/fits_reader/shelf.py in calc_ramp_data(self, folder_name, arm_name)
#     394     def calc_ramp_data(self,folder_name,arm_name,):
#     395         cut_area = self.cut_area
# --> 396         times, data_image_minus_reset = self._get_data(arm_name,folder_name)
#     397         if times == []:
#     398             return [],[],[]
#
# ~/python/main/calibration/fits_reader/shelf.py in _get_data(self, arm_name, folder_name)
#     384
#     385         if self.isMask:
# --> 386             mask,_ = fits_reader.loadMask(ch)
#     387             data_image = data_image * mask
#     388             if self.minus_reset_frame:
#
# ~/python/main/calibration/fits_reader/fits_reader.py in loadMask(ch)
#     138 def loadMask(ch,):
#     139     f = "./lib/mask/" + ch + "mask.fts"
# --> 140     masks, header = loadFits(f)
#     141     mask = np.nanmean(masks, axis=0)
#     142     return mask,header
#
# ~/python/main/calibration/fits_reader/fits_reader.py in loadFits(fileName)
#      23     for i,hdu in enumerate(hdulist):
#      24         data=np.array(hdu.data / (4*10**(-6)),dtype=np.float32)
# ---> 25         data_np[i] = data
#      26     header=hdu.header
#      27     return data_np, header
#
# ValueError: could not broadcast input array from shape (2,2048,2048) into shape (2048,2048)

# %%
fig3.set_figwidth(9)
fig3.set_figheight(5)
display(fig3)
ax3.set_ylim(-1000,10000)
ax3.set_xlim(100,500)
display(fig3)
