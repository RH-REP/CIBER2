# %%
# %load_ext memory_profiler
# %matplotlib notebook

import matplotlib.pyplot as plt
import matplotlib
import os
from fitsReader import shelf
from fitsReader import fitsReader
import importlib
import glob
import spec_reader
importlib.reload(fitsReader)
importlib.reload(shelf)
importlib.reload(spec_reader.spec_reader)
importlib.reload(spec_reader.irradiance)
import gc
import math
# Out:
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler

# %%
home_directory = os.environ['HOME']
datadirectory = home_directory + '/spectrometer/wsmr_measurement/20210528_WSMR1/'
d = "0mm"
measuredFiles = glob.glob(datadirectory + d +"*")
bgFiles = glob.glob(datadirectory +"BG_"+ d+"*")
matsumi_baffle = spec_reader.angle_function.BaffleClass('sp1_40deg_kiwami.csv','sp1_base_20210401.csv')
ls_irradiance_class= spec_reader.irradiance.IrradianceClass(measuredFiles,bgFiles,matsumi_baffle)

# %%
arms = ["armS","armM","armL"]
home_directory = os.environ['HOME']
season_name = "/WSMR2021May/reduction/2021-06-23"
experiment_name = "/abs_calib/vis/"
experiment_directory = home_directory + season_name + experiment_name
eps_shelf = shelf.make_eps_shelf(experiment_directory)

# %%
OD = "OD1"
arm_name = "armS"
cf_class = spec_reader.irradiance.CF_Class(eps_shelf,ls_irradiance_class,OD,arm_name)
# Out:
# /home/ciber2/python/main/calibration/fitsReader/shelf.py:79: RuntimeWarning: Mean of empty slice
#   img = np.nanmean(imgs,axis=0)

# %%
cf_class.show_wv_vs_eps_lvf()

# %%
cf_class.show_wv_vs_irradiance()

# %%
cf_class.show_wv_vs_cf()

# %%
ODs = ["OD1","OD2","OD3"]
cf_classes = {}
arm_name = "armS"
fig,ax = plt.subplots()
for OD in ODs:
    cf_classes[OD] = spec_reader.irradiance.CF_Class(eps_shelf,ls_irradiance_class,OD,arm_name)
for OD in ODs:
    cf_class = cf_class[OD]
    ax.scatter(cf_class.waves_spec,cf_class.ls_irradinance_reduced,label= OD+" reduced")
ax.legend()
ax.set_xlabel("wavelength [nm]")
ax.set_ylabel("abs irradiance [W/m^2/nm]")
ax.set_ylim(1*10**-9,0.01)
ax.set_yscale("log")

# %%
fig,ax = plt.subplots()
for OD in ODs:
    cf_class = cf_classes[OD]
    ax.scatter(cf_class.waves_lvf,cf_class.cf,label= OD+" reduced")

w,cf= spec_reader.irradiance.get_cf_from_theory()
ax.scatter(w,cf,label= "theory")

ax.legend()
ax.set_xlim(500,1000)
ax.set_ylim(10**-10,10**-8)
ax.set_yscale("log")
ax.set_xlabel("wavelength [nm]")
ax.set_ylabel("CF[radiance/eps]")
# Out:
# Text(0, 0.5, 'CF[radiance/eps]')

# %%
fig,ax =irradiance_class.show_wave_and_irradiance()
ax.set_ylim(0,0.00004)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1c28ac117366> in <module>
# ----> 1 fig,ax =irradiance_class.show_wave_and_irradiance()
#       2 ax.set_ylim(0,0.00004)
#
# NameError: name 'irradiance_class' is not defined

# %%
OD = "OD1"
eps_shelf.show_eps_image(OD,"armS")
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
waves_lvf, eps_lvf = eps_shelf.getLVFxy(OD,"armS")
fig,ax = plt.subplots()
ax.scatter(waves_lvf, eps_lvf)
ax.set_xlabel("wavelength [nm]")
ax.set_ylabel("eps")
# Out:
# Text(0, 0.5, 'eps')

# %%
waves_spec,irradiance_spec = irradiance_class.waves,irradiance_class.irradiance
file = './lib/filter/'+OD+'.csv'
rawData_np = spec_reader.spec_reader.csv_to_np(file,isHeaderExist=True)
w,transparent = rawData_np.T[0],rawData_np.T[1]
irradiance_spec_reduced = irradiance_spec * transparent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ad3fac3d5ed1> in <module>
# ----> 1 waves_spec,irradiance_spec = irradiance_class.waves,irradiance_class.irradiance
#       2 file = './lib/filter/'+OD+'.csv'
#       3 rawData_np = spec_reader.spec_reader.csv_to_np(file,isHeaderExist=True)
#       4 w,transparent = rawData_np.T[0],rawData_np.T[1]
#       5 irradiance_spec_reduced = irradiance_spec * transparent
#
# NameError: name 'irradiance_class' is not defined

# %%
plt.scatter(waves_spec,irradiance_spec,label="measured")
plt.scatter(waves_spec,irradiance_spec_reduced,label= OD+" reduced")
plt.legend()
plt.xlabel("wavelength [nm]")
plt.ylabel("abs irradiance [uW/cm^2/nm]")
plt.legend()
plt.ylim(1*10**-7,0.01)
plt.yscale("log")

# %%
from scipy import interpolate
irradiance_spec_reduced_ip = interpolate.interp1d(waves_spec,irradiance_spec_reduced,fill_value="extrapolate")(waves_lvf)

# %%
cf = irradiance_spec_reduced_ip/eps_lvf/math.pi * 0.76*1.2

# %%
f = './spec_reader/spec_lib/20210629_cf.csv'
raw = spec_reader.spec_reader.csv_to_np(f,isHeaderExist=True)
w,ti = raw.T[0],raw.T[1]

# %%
# fig,ax = plt.subplots()
# print(wave_lvf[600])
# ax.scatter(wave_lvf,cf/cf[600],label="measured")
# ax.scatter(w,ti/ti[100],label="calc")
# ax.legend()
# ax.set_xlim(500,1000)
# # ax.set_yscale("log")
# ax.set_ylim(0,2)
# ax.set_xlabel("wavelength [nm]")
# ax.set_ylabel("CF")

# %%
fig,ax = plt.subplots()
ax.scatter(waves_lvf,cf,label="measured")
ax.scatter(w,ti,label="calc")
ax.legend()
ax.set_xlim(500,1000)
ax.set_ylim(10**-10,10**-8)
ax.set_yscale("log")
ax.set_xlabel("wavelength [nm]")
ax.set_ylabel("CF[radiance/eps]")
# Out:
# Text(0, 0.5, 'CF[radiance/eps]')
