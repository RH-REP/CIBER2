# %% [markdown]
# # リセットフレームの調査
# ![image.png](attachment:image.png)

# %%
import glob
import os
from fits_reader import fits_reader
from fits_reader import shelf
import numpy as np
import importlib
import matplotlib.pyplot as plt

importlib.reload(fits_reader)
importlib.reload(shelf)

home_directory = os.environ['HOME']
season_name = "/WSMR2021May"
experiment_name = "/abs_calib/NIR"
experiment_directory = home_directory + season_name + experiment_name
# chs = ["ch3"]
chs = ["ch1","ch2","ch3"]
cutArea = fits_reader.AreaSizeClass(1100,1200,1400,1500)


plot_data_set = {}
plot_data_set_std= {}
# exp_shelf = shelf.make_ramp_shelf(experiment_directory,)
for ch in chs:
    folders = glob.glob(experiment_directory+"/frames/"+ ch + "/*")
    folders_contain_reset = fits_reader.getResetFitsFolder(folders) 
    exp_shelf = shelf.make_ramp_shelf(experiment_directory,)
    exp_shelf.line_up_by_folders(ch,folders_contain_reset)

# %%
# exp_shelf.line_up_by_folders("reset",experiment_directory)
# exp_shelf.show_all_numbers("reset")

# %%
# exp_shelf.take_book("reset").get_data_numbers()# exp_shelf.take_book("reset").get_data_numbers()
fig,ax = exp_shelf.make_ramp_graph(ch,"armS",cutArea)

# %%
exp_shelf.make_times_vs_counts_graph("ch1","armL",cutArea)

# %%
exp_shelf.make_times_vs_counts_graph("ch2","armM",cutArea)
# Out:
# <img src="data:image/png;base64,..." width="639.9">
# memory size is  0.19 GB
# memory size is  0.41 GB
# memory size is  0.16 GB
# memory size is  0.81 GB
# memory size is  0.19 GB
# memory size is  0.19 GB
# memory size is  0.16 GB
# memory size is  0.47 GB
# memory size is  0.78 GB
# memory size is  0.47 GB
# memory size is  0.19 GB
# memory size is  0.19 GB
# memory size is  0.19 GB
# memory size is  0.19 GB
# memory size is  0.81 GB
# memory size is  0.81 GB
# memory size is  0.22 GB
# memory size is  0.19 GB
# memory size is  0.16 GB
# memory size is  0.19 GB
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:title={'center':'ch2-armM'}, xlabel='time[s]', ylabel='electrons'>)

# %%
exp_shelf.make_times_vs_counts_graph("ch3","armS",cutArea)
# Out:
# <img src="data:image/png;base64,..." width="639.9">
# memory size is  0.19 GB
# memory size is  0.16 GB
# memory size is  0.16 GB
# memory size is  0.84 GB
# memory size is  0.84 GB
# memory size is  0.19 GB
# memory size is  0.84 GB
# memory size is  0.19 GB
# memory size is  0.19 GB
# memory size is  0.19 GB
# memory size is  0.16 GB
# memory size is  0.19 GB
# memory size is  0.41 GB
# memory size is  0.19 GB
# memory size is  0.5 GB
# memory size is  0.84 GB
# memory size is  0.16 GB
# memory size is  0.81 GB
# memory size is  0.47 GB
# memory size is  0.44 GB
# memory size is  0.16 GB
# memory size is  0.44 GB
# memory size is  0.16 GB
# memory size is  0.16 GB
# memory size is  0.44 GB
# memory size is  0.81 GB
# memory size is  0.19 GB
# memory size is  0.81 GB
# memory size is  0.16 GB
# memory size is  0.81 GB
# memory size is  0.75 GB
# memory size is  0.19 GB
# memory size is  0.19 GB
# (<Figure size 640x480 with 1 Axes>,
# ...
