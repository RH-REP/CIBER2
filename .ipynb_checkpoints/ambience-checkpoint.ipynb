# %%
import matplotlib.pyplot as plt
import os
from fitsReader import shelf
from fitsReader import fitsReader
import importlib
import glob
importlib.reload(fitsReader)
importlib.reload(shelf)
import gc
# %matplotlib notebook

home_directory = os.environ['HOME']
season_name = "/WSMR2021May"
experiment_name = "/ambience/May19"
experiment_directory = home_directory + season_name + experiment_name
# make_shelf(experiment_directory)

exp_shelf = shelf.make_shelf(experiment_directory)
exp_shelf.line_up_by_excel()
arms = ["armS","armM","armL"]
figs = {}
axs = {}
exp_data = {}
full_names = []
cutArea = fitsReader.AreaSizeClass(1100,1200,1400,1500)

# %%
exp_shelf.get_all_books()
# Out:
# ['Silver mask', 'Black mask']

# %%
configuration_name = "Silver mask"
arm_name = "armS"
# full_name = configuration_name + "-" + arm_name
# if not (full_name in full_names) : full_names.append(full_name) 
fig,ax = exp_shelf.make_ramp_graph(configuration_name,arm_name,cutArea,isLinearFit=True,)
# Out:
# <img src="data:image/png;base64,..." width="640">
# memory size is  0.39 GB
# memory size is  1.2 GB
# memory size is  1.1 GB
# memory size is  0.88 GB
# memory size is  1.2 GB
# memory size is  1.1 GB

# %%
configuration_name = "Black mask"
arm_name = "armS"
# full_name = configuration_name + "-" + arm_name
# if not (full_name in full_names) : full_names.append(full_name) 
fig,ax = exp_shelf.make_times_vs_counts_graph(configuration_name,arm_name,cutArea,isLinearFit=True,isbg=False)
# Out:
# <img src="data:image/png;base64,..." width="640">
# memory size is  0.078 GB
# memory size is  1.1 GB
# memory size is  1.2 GB
# memory size is  1.2 GB
# memory size is  1.1 GB
# memory size is  1.2 GB

# %%
fig, ax = plt.subplots()
a = [0,1,2]
b = [2,3,5]
lineobject = ax.plot(a,b)
# Out:
# <img src="data:image/png;base64,..." width="640">
